# %%
# Supress Warnings

import warnings
warnings.filterwarnings('ignore')

# %%
# Import the numpy and pandas packages

import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Task 1: Reading and Inspection
#
# -  ### Subtask 1.1: Import and read
#
# Import and read the movie database. Store it in a variable called `movies`.

# %%
#movies = # Write your code for importing the csv file here

movies = pd.read_csv('Movie+Assignment+Data.csv')
movies
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color                NaN                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %% [markdown]
# -  ### Subtask 1.2: Inspect the dataframe
#
# Inspect the dataframe's columns, shapes, variable types etc.

# %%
# Write your code for inspection here

print("The DataFrame has:", len(movies), "rows")
print("The DataFrame has:", len(movies.columns), "columns")
print("The DataFrame shape is", movies.shape)
print("The DataFrame size is", movies.size, "element")
print("The variable_type as as follows,\n\n")
movies.dtypes
# Out:
# The DataFrame has: 5043 rows
# The DataFrame has: 28 columns
# The DataFrame shape is (5043, 28)
# The DataFrame size is 141204 element
# The variable_type as as follows,
# color                         object
# director_name                 object
# num_critic_for_reviews       float64
# duration                     float64
# director_facebook_likes      float64
# actor_3_facebook_likes       float64
# actor_2_name                  object
# actor_1_facebook_likes       float64
# gross                        float64
# genres                        object
# actor_1_name                  object
# movie_title                   object
# num_voted_users                int64
# cast_total_facebook_likes      int64
# actor_3_name                  object
# facenumber_in_poster         float64
# plot_keywords                 object
# movie_imdb_link               object
# num_user_for_reviews         float64
# language                      object
# country                       object
# ...

# %% [markdown]
# ## Task 2: Cleaning the Data
#
# -  ### Subtask 2.1: Inspect Null values
#
# Find out the number of Null values in all the columns and rows. Also, find the percentage of Null values in each column. Round off the percentages upto two decimal places.

# %%
# Write your code for column-wise null count here

null_values_per_column = movies.isnull().sum()
print("Column-wise null count:")
print('_________________________')
print(null_values_per_column)
# Out:
# Column-wise null count:
# _________________________
# color                         19
# director_name                104
# num_critic_for_reviews        50
# duration                      15
# director_facebook_likes      104
# actor_3_facebook_likes        23
# actor_2_name                  13
# actor_1_facebook_likes         7
# gross                        884
# genres                         0
# actor_1_name                   7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster          13
# plot_keywords                153
# movie_imdb_link                0
# num_user_for_reviews          21
# language                      14
# country                        5
# content_rating               303
# budget                       492
# title_year                   108
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 329
# ...

# %%
# Write your code for row-wise null count here

null_values_per_row = movies.isnull().sum(axis=1)
print("Row-wise null counts:")
print('_______________________')
print(null_values_per_row)
# Out:
# Row-wise null counts:
# _______________________
# 0        0
# 1        0
# 2        0
# 3        0
# 4       14
#         ..
# 5038     4
# 5039     5
# 5040     4
# 5041     2
# 5042     0
# Length: 5043, dtype: int64

# %%
# Write your code for column-wise null percentages here

total_rows = len(movies)
percentage_null_per_column = (movies.isnull().sum() / total_rows) * 100
percentage_null_per_column = percentage_null_per_column.round(2)
print("Column-wise null percentage:")
print(percentage_null_per_column)
# Out:
# Column-wise null percentage:
# color                         0.38
# director_name                 2.06
# num_critic_for_reviews        0.99
# duration                      0.30
# director_facebook_likes       2.06
# actor_3_facebook_likes        0.46
# actor_2_name                  0.26
# actor_1_facebook_likes        0.14
# gross                        17.53
# genres                        0.00
# actor_1_name                  0.14
# movie_title                   0.00
# num_voted_users               0.00
# cast_total_facebook_likes     0.00
# actor_3_name                  0.46
# facenumber_in_poster          0.26
# plot_keywords                 3.03
# movie_imdb_link               0.00
# num_user_for_reviews          0.42
# language                      0.28
# country                       0.10
# content_rating                6.01
# budget                        9.76
# title_year                    2.14
# actor_2_facebook_likes        0.26
# imdb_score                    0.00
# ...

# %% [markdown]
# -  ### Subtask 2.2: Drop unecessary columns
#
# For this assignment, you will mostly be analyzing the movies with respect to the ratings, gross collection, popularity of movies, etc. So many of the columns in this dataframe are not required. So it is advised to drop the following columns.
# -  color
# -  director_facebook_likes
# -  actor_1_facebook_likes
# -  actor_2_facebook_likes
# -  actor_3_facebook_likes
# -  actor_2_name
# -  cast_total_facebook_likes
# -  actor_3_name
# -  duration
# -  facenumber_in_poster
# -  content_rating
# -  country
# -  movie_imdb_link
# -  aspect_ratio
# -  plot_keywords

# %%
# Write your code for dropping the columns here. It is advised to keep inspecting the dataframe after each set of operations 

columns_to_drop = ['color','director_facebook_likes','actor_1_facebook_likes','actor_2_facebook_likes','actor_3_facebook_likes','actor_2_name','actor_3_name','cast_total_facebook_likes','duration','facenumber_in_poster','content_rating','country','movie_imdb_link','aspect_ratio','plot_keywords']

columns_to_drop = [col for col in columns_to_drop if col in movies.columns]
movies.drop(columns=columns_to_drop, inplace=True)
movies
# Out:
#           director_name  num_critic_for_reviews       gross  \
# 0         James Cameron                   723.0  760.505847
# 1        Gore Verbinski                   302.0  309.404152
# 2            Sam Mendes                   602.0  200.074175
# 3     Christopher Nolan                   813.0  448.130642
# 4           Doug Walker                     NaN         NaN
# ...                 ...                     ...         ...
# 5038        Scott Smith                     1.0         NaN
# 5039                NaN                    43.0         NaN
# 5040   Benjamin Roberds                    13.0         NaN
# 5041        Daniel Hsia                    14.0    0.010443
# 5042           Jon Gunn                    43.0    0.085222
#
#                                genres     actor_1_name  \
# 0     Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1            Action|Adventure|Fantasy      Johnny Depp
# 2           Action|Adventure|Thriller  Christoph Waltz
# ...

# %% [markdown]
# -  ### Subtask 2.3: Drop unecessary rows using columns with high Null percentages
#
# Now, on inspection you might notice that some columns have large percentage (greater than 5%) of Null values. Drop all the rows which have Null values for such columns.

# %%
null_percentage = (movies.isnull().sum() / len(movies)) * 100

columns_to_drop = null_percentage[null_percentage > 5].index

movies2= movies.dropna(subset=columns_to_drop)

movies2
# Out:
#           director_name  num_critic_for_reviews       gross  \
# 0         James Cameron                   723.0  760.505847
# 1        Gore Verbinski                   302.0  309.404152
# 2            Sam Mendes                   602.0  200.074175
# 3     Christopher Nolan                   813.0  448.130642
# 5        Andrew Stanton                   462.0   73.058679
# ...                 ...                     ...         ...
# 5033      Shane Carruth                   143.0    0.424760
# 5034   Neill Dela Llana                    35.0    0.070071
# 5035   Robert Rodriguez                    56.0    2.040920
# 5037       Edward Burns                    14.0    0.004584
# 5042           Jon Gunn                    43.0    0.085222
#
#                                    genres     actor_1_name  \
# 0         Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1                Action|Adventure|Fantasy      Johnny Depp
# 2               Action|Adventure|Thriller  Christoph Waltz
# ...

# %%
# Write your code for dropping the rows here

null_percentage = (movies.isnull().sum() / len(movies)) * 100

columns_to_drop = null_percentage[null_percentage > 5].index

movies_cleaned= movies.dropna(subset=columns_to_drop)

movies_cleaned
# Out:
#           director_name  num_critic_for_reviews        gross  \
# 0         James Cameron                   723.0  760505847.0
# 1        Gore Verbinski                   302.0  309404152.0
# 2            Sam Mendes                   602.0  200074175.0
# 3     Christopher Nolan                   813.0  448130642.0
# 5        Andrew Stanton                   462.0   73058679.0
# ...                 ...                     ...          ...
# 5033      Shane Carruth                   143.0     424760.0
# 5034   Neill Dela Llana                    35.0      70071.0
# 5035   Robert Rodriguez                    56.0    2040920.0
# 5037       Edward Burns                    14.0       4584.0
# 5042           Jon Gunn                    43.0      85222.0
#
#                                    genres     actor_1_name  \
# 0         Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1                Action|Adventure|Fantasy      Johnny Depp
# ...

# %% [markdown]
# -  ### Subtask 2.4: Fill NaN values
#
# You might notice that the `language` column has some NaN values. Here, on inspection, you will see that it is safe to replace all the missing values with `'English'`.

# %%
# Write your code for filling the NaN values in the 'language' column here
import warnings
warnings.filterwarnings('ignore')

language = 'English'
movies_cleaned['language'].fillna(language, inplace=True)

print("DataFrame after filling NaN values in the 'language'column:")
(movies_cleaned['language'])
# Out:
# DataFrame after filling NaN values in the 'language'column:
# 0       English
# 1       English
# 2       English
# 3       English
# 5       English
#          ...
# 5033    English
# 5034    English
# 5035    Spanish
# 5037    English
# 5042    English
# Name: language, Length: 3891, dtype: object

# %% [markdown]
# -  ### Subtask 2.5: Check the number of retained rows
#
# You might notice that two of the columns viz. `num_critic_for_reviews` and `actor_1_name` have small percentages of NaN values left. You can let these columns as it is for now. Check the number and percentage of the rows retained after completing all the tasks above.

# %%
# Write your code for checking number of retained rows here

retained_rows = len(movies_cleaned)
percentage_retained = (retained_rows / total_rows) * 100
print("Number of retained rows:", retained_rows)
print("Percentage of retained rows:", round(percentage_retained, 2), "%")
# Out:
# Number of retained rows: 3891
# Percentage of retained rows: 77.16 %

# %% [markdown]
# **Checkpoint 1:** You might have noticed that we still have around `77%` of the rows!

# %% [markdown]
# ## Task 3: Data Analysis
#
# -  ### Subtask 3.1: Change the unit of columns
#
# Convert the unit of the `budget` and `gross` columns from `$` to `million $`.

# %%
# Write your code for unit conversion here

import warnings
warnings.filterwarnings('ignore')

movies['budget'] = movies['budget'].apply(lambda x: x/1000000)
movies['gross'] = movies['gross'].apply(lambda x: x/1000000)
print("DataFrame after unit conversion to million $: budget")
print(movies_cleaned['budget'])
print("_______________________________________________________")
print("DataFrame after unit conversion to million $: gross")
print(movies_cleaned['gross'])
# Out:
# DataFrame after unit conversion to million $: budget
# _______________________________________________________
# DataFrame after unit conversion to million $: gross
# 0       760505847.0
# 1       309404152.0
# 2       200074175.0
# 3       448130642.0
# 5        73058679.0
#            ...
# 5033       424760.0
# 5034        70071.0
# 5035      2040920.0
# 5037         4584.0
# 5042        85222.0
# Name: gross, Length: 3891, dtype: float64

# %% [markdown]
# -  ### Subtask 3.2: Find the movies with highest profit
#
#     1. Create a new column called `profit` which contains the difference of the two columns: `gross` and `budget`.
#     2. Sort the dataframe using the `profit` column as reference.
#     3. Plot `profit` (y-axis) vs `budget` (x- axis) and observe the outliers using the appropriate chart type.
#     4. Extract the top ten profiting movies in descending order and store them in a new dataframe - `top10`

# %%
# Write your code for creating the profit column here

import warnings
warnings.filterwarnings('ignore')

movies_cleaned['Profit'] = movies_cleaned['gross'] - movies_cleaned['budget']
print("DataFrame with Profit column:")
print("_______________________________")
print(movies_cleaned['Profit'])
# Out:
# DataFrame with Profit column:
# _______________________________
# 0       523505847.0
# 1         9404152.0
# 2       -44925825.0
# 3       198130642.0
# 5      -190641321.0
#            ...
# 5033       417760.0
# 5034        63071.0
# 5035      2033920.0
# 5037        -4416.0
# 5042        84122.0
# Name: Profit, Length: 3891, dtype: float64

# %%
# Write your code for sorting the dataframe here

movies_cleaned_sort = movies_cleaned.sort_values(by='Profit', ascending=False)
Profit = movies_cleaned_sort['Profit']
print("DataFrame sort by Profit:")
print("____________________________")
Profit
# Out:
# DataFrame sort by Profit:
# ____________________________
# 0       5.235058e+08
# 29      5.021773e+08
# 26      4.586723e+08
# 3024    4.499357e+08
# 3080    4.244495e+08
#             ...
# 2334   -2.127110e+09
# 2323   -2.397702e+09
# 3005   -2.499804e+09
# 3859   -4.199788e+09
# 2988   -1.221330e+10
# Name: Profit, Length: 3891, dtype: float64

# %%
# Write code for profit vs budget plot here

import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.scatter(movies_cleaned['budget'], movies_cleaned['Profit'],color='blue', alpha=0.7)
plt.title('Profit vs. Budget')
plt.xlabel('Budget')
plt.ylabel('Profit')
plt.grid(True)
plt.show()

# %%
#top10 = # Write your code to get the top 10 profiting movies here

top10 = movies_cleaned.sort_values(by= 'Profit', ascending=False).head(10)
print("Top 10 Profiting Movies DataFrame:")
print("___________________________________")
top10
# Out:
# Top 10 Profiting Movies DataFrame:
# ___________________________________
#           director_name  num_critic_for_reviews        gross  \
# 0         James Cameron                   723.0  760505847.0
# 29      Colin Trevorrow                   644.0  652177271.0
# 26        James Cameron                   315.0  658672302.0
# 3024       George Lucas                   282.0  460935665.0
# 3080   Steven Spielberg                   215.0  434949459.0
# 794         Joss Whedon                   703.0  623279547.0
# 17          Joss Whedon                   703.0  623279547.0
# 509        Roger Allers                   186.0  422783777.0
# 240        George Lucas                   320.0  474544677.0
# 66    Christopher Nolan                   645.0  533316061.0
#
#                                         genres         actor_1_name  \
# 0              Action|Adventure|Fantasy|Sci-Fi          CCH Pounder
# 29            Action|Adventure|Sci-Fi|Thriller  Bryce Dallas Howard
# ...

# %% [markdown]
# -  ### Subtask 3.3: Drop duplicate values
#
# After you found out the top 10 profiting movies, you might have noticed a duplicate value. So, it seems like the dataframe has duplicate values as well. Drop the duplicate values from the dataframe and repeat `Subtask 3.2`. Note that the same `movie_title` can be there in different languages.

# %%
# Write your code for dropping duplicate values here

top10 = top10.drop_duplicates()
top10
# Out:
#           director_name  num_critic_for_reviews        gross  \
# 0         James Cameron                   723.0  760505847.0
# 29      Colin Trevorrow                   644.0  652177271.0
# 26        James Cameron                   315.0  658672302.0
# 3024       George Lucas                   282.0  460935665.0
# 3080   Steven Spielberg                   215.0  434949459.0
# 794         Joss Whedon                   703.0  623279547.0
# 509        Roger Allers                   186.0  422783777.0
# 240        George Lucas                   320.0  474544677.0
# 66    Christopher Nolan                   645.0  533316061.0
#
#                                         genres         actor_1_name  \
# 0              Action|Adventure|Fantasy|Sci-Fi          CCH Pounder
# 29            Action|Adventure|Sci-Fi|Thriller  Bryce Dallas Howard
# 26                               Drama|Romance    Leonardo DiCaprio
# 3024           Action|Adventure|Fantasy|Sci-Fi        Harrison Ford
# ...

# %%
# Write code for repeating subtask 2 here

top10_no_duplicates = top10.drop_duplicates()
top10_highest_profit_no_duplicates = top10_no_duplicates.sort_values(by='Profit', ascending=False).head(10)
print("Top 10 movies with the highest profit after dropping duplicates:")
print("__________________________________________________________________")
top10_highest_profit_no_duplicates
# Out:
# Top 10 movies with the highest profit after dropping duplicates:
# __________________________________________________________________
#           director_name  num_critic_for_reviews        gross  \
# 0         James Cameron                   723.0  760505847.0
# 29      Colin Trevorrow                   644.0  652177271.0
# 26        James Cameron                   315.0  658672302.0
# 3024       George Lucas                   282.0  460935665.0
# 3080   Steven Spielberg                   215.0  434949459.0
# 794         Joss Whedon                   703.0  623279547.0
# 509        Roger Allers                   186.0  422783777.0
# 240        George Lucas                   320.0  474544677.0
# 66    Christopher Nolan                   645.0  533316061.0
#
#                                         genres         actor_1_name  \
# 0              Action|Adventure|Fantasy|Sci-Fi          CCH Pounder
# 29            Action|Adventure|Sci-Fi|Thriller  Bryce Dallas Howard
# ...

# %% [markdown]
# **Checkpoint 2:** You might spot two movies directed by `James Cameron` in the list.

# %% [markdown]
# -  ### Subtask 3.4: Find IMDb Top 250
#
#     1. Create a new dataframe `IMDb_Top_250` and store the top 250 movies with the highest IMDb Rating (corresponding to the column: `imdb_score`). Also make sure that for all of these movies, the `num_voted_users` is greater than 25,000.
# Also add a `Rank` column containing the values 1 to 250 indicating the ranks of the corresponding films.
#     2. Extract all the movies in the `IMDb_Top_250` dataframe which are not in the English language and store them in a new dataframe named `Top_Foreign_Lang_Film`.

# %%
# Write your code for extracting the top 250 movies as per the IMDb score here. Make sure that you store it in a new dataframe 
# and name that dataframe as 'IMDb_Top_250'

IMDb_Top_250 = movies_cleaned[movies_cleaned['num_voted_users'] > 2500].nlargest(250,'imdb_score').copy()
IMDb_Top_250['rank'] = range(1, 251)

print("IMDb_Top_250 Movies:")
print("_________________________")
IMDb_Top_250
# Out:
# IMDb_Top_250 Movies:
# _________________________
#              director_name  num_critic_for_reviews        gross  \
# 1937        Frank Darabont                   199.0   28341469.0
# 3466  Francis Ford Coppola                   208.0  134821952.0
# 66       Christopher Nolan                   645.0  533316061.0
# 2837  Francis Ford Coppola                   149.0   57300000.0
# 339          Peter Jackson                   328.0  377019252.0
# ...                    ...                     ...          ...
# 2492        John Carpenter                   318.0   47000000.0
# 2493           Yimou Zhang                   283.0      84961.0
# 2558          Edgar Wright                   285.0   23618786.0
# 2605               Ang Lee                   287.0  128067808.0
# 2619        John Carpenter                   318.0   47000000.0
#
#                               genres      actor_1_name  \
# 1937                     Crime|Drama    Morgan Freeman
# ...

# %%
#Top_Foreign_Lang_Film = # Write your code to extract top foreign language films from 'IMDb_Top_250' here

Top_Foreign_Lang_Film = IMDb_Top_250[IMDb_Top_250['language'] !='English'].copy()
print("Top Foreign Language Film DataFrame:")
print("_______________________________________")
Top_Foreign_Lang_Film
# Out:
# Top Foreign Language Film DataFrame:
# _______________________________________
#                          director_name  num_critic_for_reviews        gross  \
# 4498                      Sergio Leone                   181.0    6100000.0
# 4029                Fernando Meirelles                   214.0    7563397.0
# 4747                    Akira Kurosawa                   153.0     269061.0
# 2373                    Hayao Miyazaki                   246.0   10049886.0
# 4259  Florian Henckel von Donnersmarck                   215.0   11284657.0
# 4921                      Majid Majidi                    46.0     925402.0
# 1298                Jean-Pierre Jeunet                   242.0   33201661.0
# 1329                    S.S. Rajamouli                    44.0    6498000.0
# 2323                    Hayao Miyazaki                   174.0    2298191.0
# 2970                 Wolfgang Petersen                    96.0   11433134.0
# ...

# %% [markdown]
# Checkpoint 3:Can you spot `Veer-Zaara` in the dataframe?

# %% [markdown]
# - ### Subtask 3.5: Find the best directors
#
#     1. Group the dataframe using the `director_name` column.
#     2. Find out the top 10 directors for whom the mean of `imdb_score` is the highest and store them in a new dataframe `top10director`.  Incase of a tie in IMDb score between two directors, sort them alphabetically.

# %%
# Write your code for extracting the top 10 directors here

directors_mean_imdb = movies_cleaned.groupby('director_name')['imdb_score'].mean()
top10_directors = directors_mean_imdb.reset_index().sort_values(by=['imdb_score', 'director_name'],ascending=[False, True]).head(10)
print ("Top 10 Directors by Mean IMDb Score:")
print("________________________________________")
top10_directors
# Out:
# Top 10 Directors by Mean IMDb Score:
# ________________________________________
#               director_name  imdb_score
# 216         Charles Chaplin    8.600000
# 1675              Tony Kaye    8.600000
# 45         Alfred Hitchcock    8.500000
# 302         Damien Chazelle    8.500000
# 1017           Majid Majidi    8.500000
# 1440             Ron Fricke    8.500000
# 1498           Sergio Leone    8.433333
# 260       Christopher Nolan    8.425000
# 103          Asghar Farhadi    8.400000
# 1035  Marius A. Markevicius    8.400000

# %% [markdown]
# **Checkpoint 4:** No surprises that `Damien Chazelle` (director of Whiplash and La La Land) is in this list.

# %% [markdown]
# -  ### Subtask 3.6: Find popular genres
#
# You might have noticed the `genres` column in the dataframe with all the genres of the movies seperated by a pipe (`|`). Out of all the movie genres, the first two are most significant for any film.
#
# 1. Extract the first two genres from the `genres` column and store them in two new columns: `genre_1` and `genre_2`. Some of the movies might have only one genre. In such cases, extract the single genre into both the columns, i.e. for such movies the `genre_2` will be the same as `genre_1`.
# 2. Group the dataframe using `genre_1` as the primary column and `genre_2` as the secondary column.
# 3. Find out the 5 most popular combo of genres by finding the mean of the gross values using the `gross` column and store them in a new dataframe named `PopGenre`.

# %%
# Write your code for extracting the first two genres of each movie here

genres_split = movies_cleaned['genres'].str.split('|', n=1, expand=True)
movies_cleaned['genre_1'] = genres_split[0]
movies_cleaned['genre_2'] = genres_split[1]
movies_cleaned['genre_2'].fillna(movies_cleaned['genre_1'], inplace=True)
print("DataFrame with genre_1 and genre_2 columns:")
print("_______________________________________________")
movies_cleaned[['genre_1', 'genre_2']]
# Out:
# DataFrame with genre_1 and genre_2 columns:
# _______________________________________________
#           genre_1                       genre_2
# 0          Action      Adventure|Fantasy|Sci-Fi
# 1          Action             Adventure|Fantasy
# 2          Action            Adventure|Thriller
# 3          Action                      Thriller
# 5          Action              Adventure|Sci-Fi
# ...           ...                           ...
# 5033        Drama               Sci-Fi|Thriller
# 5034     Thriller                      Thriller
# 5035       Action  Crime|Drama|Romance|Thriller
# 5037       Comedy                         Drama
# 5042  Documentary                   Documentary
#
# [3891 rows x 2 columns]

# %%
#movies_by_segment = # Write your code for grouping the dataframe here

movies_by_segment = movies_cleaned.groupby(['genre_1', 'genre_2'])
print("Movies_by_segment:")
print("_______________________________")
movies_by_segment.size().reset_index(name='count')
# Out:
# Movies_by_segment:
# _______________________________
#       genre_1                                          genre_2  count
# 0      Action                                           Action      6
# 1      Action                                        Adventure     10
# 2      Action  Adventure|Animation|Comedy|Crime|Family|Fantasy      1
# 3      Action   Adventure|Animation|Comedy|Drama|Family|Sci-Fi      2
# 4      Action                Adventure|Animation|Comedy|Family      5
# ..        ...                                              ...    ...
# 757   Romance                                  Sci-Fi|Thriller      1
# 758    Sci-Fi                                           Sci-Fi      1
# 759    Sci-Fi                                         Thriller      7
# 760  Thriller                                         Thriller      3
# 761   Western                                          Western      3
#
# [762 rows x 3 columns]

# %%
#PopGenre = # Write your code for getting the 5 most popular combo of genres here

PopGenre = movies_cleaned.groupby(['genre_1', 'genre_2']).mean('gross').sort_values(by='gross', ascending=False).head(5)
print("Top 5 Most PopGenre:")
print("______________________")
PopGenre[['gross']]
# Out:
# Top 5 Most PopGenre:
# ______________________
#                                                         gross
# genre_1   genre_2
# Family    Sci-Fi                                 4.349495e+08
# Adventure Animation|Drama|Family|Musical         4.227838e+08
#           Animation|Comedy|Drama|Family|Fantasy  3.564544e+08
# Action    Biography|Drama|History|Thriller|War   3.501236e+08
#           Adventure|Fantasy|Sci-Fi               2.966848e+08

# %% [markdown]
# **Checkpoint 5:** Well, as it turns out. `Family + Sci-Fi` is the most popular combo of genres out there!

# %% [markdown]
# -  ### Subtask 3.7: Find the critic-favorite and audience-favorite actors
#
#     1. Create three new dataframes namely, `Meryl_Streep`, `Leo_Caprio`, and `Brad_Pitt` which contain the movies in which the actors: 'Meryl Streep', 'Leonardo DiCaprio', and 'Brad Pitt' are the lead actors. Use only the `actor_1_name` column for extraction. Also, make sure that you use the names 'Meryl Streep', 'Leonardo DiCaprio', and 'Brad Pitt' for the said extraction.
#     2. Append the rows of all these dataframes and store them in a new dataframe named `Combined`.
#     3. Group the combined dataframe using the `actor_1_name` column.
#     4. Find the mean of the `num_critic_for_reviews` and `num_users_for_review` and identify the actors which have the highest mean.
#     5. Observe the change in number of voted users over decades using a bar chart. Create a column called `decade` which represents the decade to which every movie belongs to. For example, the  `title_year`  year 1923, 1925 should be stored as 1920s. Sort the dataframe based on the column `decade`, group it by `decade` and find the sum of users voted in each decade. Store this in a new data frame called `df_by_decade`.

# %%
# Write your code for creating three new dataframes here

#Meryl_Streep = # Include all movies in which Meryl_Streep is the lead

Meryl_Streep = movies_cleaned[movies_cleaned['actor_1_name'] == 'Meryl Streep']
Meryl_Streep
# Out:
#        director_name  num_critic_for_reviews        gross  \
# 410     Nancy Meyers                   187.0  112703470.0
# 1106   Curtis Hanson                    42.0   46815748.0
# 1204     Nora Ephron                   252.0   94125426.0
# 1408   David Frankel                   208.0  124732962.0
# 1483  Robert Redford                   227.0   14998070.0
# 1575  Sydney Pollack                    66.0   87100000.0
# 1618   David Frankel                   234.0   63536011.0
# 1674   Carl Franklin                    64.0   23209440.0
# 1925  Stephen Daldry                   174.0   41597830.0
# 2781  Phyllida Lloyd                   331.0   29959436.0
# 3135   Robert Altman                   211.0   20338609.0
#
#                                genres  actor_1_name  \
# 410              Comedy|Drama|Romance  Meryl Streep
# 1106  Action|Adventure|Crime|Thriller  Meryl Streep
# 1204          Biography|Drama|Romance  Meryl Streep
# 1408             Comedy|Drama|Romance  Meryl Streep
# ...

# %%
#Leo_Caprio = # Include all movies in which Leo_Caprio is the lead

Leo_Caprio = movies_cleaned[movies_cleaned['actor_1_name'] == 'Leonardo DiCaprio']
Leo_Caprio
# Out:
#               director_name  num_critic_for_reviews        gross  \
# 26            James Cameron                   315.0  658672302.0
# 50             Baz Luhrmann                   490.0  144812796.0
# 97        Christopher Nolan                   642.0  292568851.0
# 179   Alejandro G. Iñárritu                   556.0  183635922.0
# 257         Martin Scorsese                   267.0  102608827.0
# 296       Quentin Tarantino                   765.0  162804648.0
# 307            Edward Zwick                   166.0   57366262.0
# 308         Martin Scorsese                   606.0  116866727.0
# 326         Martin Scorsese                   233.0   77679638.0
# 361         Martin Scorsese                   352.0  132373442.0
# 452         Martin Scorsese                   490.0  127968405.0
# 641            Ridley Scott                   238.0   39380442.0
# 911        Steven Spielberg                   194.0  164435221.0
# ...

# %%
#Brad_Pitt = # Include all movies in which Brad_Pitt is the lead

Brad_Pitt = movies_cleaned[movies_cleaned['actor_1_name'] == 'Brad Pitt']
Brad_Pitt
# Out:
#               director_name  num_critic_for_reviews        gross  \
# 101           David Fincher                   362.0  127490802.0
# 147       Wolfgang Petersen                   220.0  133228348.0
# 254       Steven Soderbergh                   198.0  125531634.0
# 255              Doug Liman                   233.0  186336103.0
# 382              Tony Scott                   142.0      26871.0
# 400       Steven Soderbergh                   186.0  183405771.0
# 470              David Ayer                   406.0   85707116.0
# 611     Jean-Jacques Annaud                    76.0   37901509.0
# 683           David Fincher                   315.0   37023395.0
# 792         Patrick Gilmore                    98.0   26288320.0
# 940             Neil Jordan                   120.0  105264608.0
# 1490        Terrence Malick                   584.0   13303319.0
# 1722         Andrew Dominik                   273.0    3904982.0
# ...

# %%
# Write your code for combining the three dataframes here

Combined = pd.concat([Meryl_Streep, Leo_Caprio, Brad_Pitt], ignore_index=True)
print("Combined DataFrame:")
Combined
# Out:
# Combined DataFrame:
#             director_name  num_critic_for_reviews        gross  \
# 0            Nancy Meyers                   187.0  112703470.0
# 1           Curtis Hanson                    42.0   46815748.0
# 2             Nora Ephron                   252.0   94125426.0
# 3           David Frankel                   208.0  124732962.0
# 4          Robert Redford                   227.0   14998070.0
# 5          Sydney Pollack                    66.0   87100000.0
# 6           David Frankel                   234.0   63536011.0
# 7           Carl Franklin                    64.0   23209440.0
# 8          Stephen Daldry                   174.0   41597830.0
# 9          Phyllida Lloyd                   331.0   29959436.0
# 10          Robert Altman                   211.0   20338609.0
# 11          James Cameron                   315.0  658672302.0
# 12           Baz Luhrmann                   490.0  144812796.0
# 13      Christopher Nolan                   642.0  292568851.0
# ...

# %%
# Write your code for grouping the combined dataframe here

grouped_combined = Combined.groupby('actor_1_name')
print("Grouped Combined DataFrame:")
grouped_combined.head(10)
# Out:
# Grouped Combined DataFrame:
#             director_name  num_critic_for_reviews        gross  \
# 0            Nancy Meyers                   187.0  112703470.0
# 1           Curtis Hanson                    42.0   46815748.0
# 2             Nora Ephron                   252.0   94125426.0
# 3           David Frankel                   208.0  124732962.0
# 4          Robert Redford                   227.0   14998070.0
# 5          Sydney Pollack                    66.0   87100000.0
# 6           David Frankel                   234.0   63536011.0
# 7           Carl Franklin                    64.0   23209440.0
# 8          Stephen Daldry                   174.0   41597830.0
# 9          Phyllida Lloyd                   331.0   29959436.0
# 11          James Cameron                   315.0  658672302.0
# 12           Baz Luhrmann                   490.0  144812796.0
# 13      Christopher Nolan                   642.0  292568851.0
# ...

# %%
# Write the code for finding the mean of critic reviews and audience reviews here

mean_reviews_by_actor = Combined.groupby('actor_1_name').agg({'num_critic_for_reviews': 'mean', 'num_user_for_reviews': 'mean'})
max_critics_actor = mean_reviews_by_actor['num_critic_for_reviews'].idxmax()
max_users_actor = mean_reviews_by_actor['num_user_for_reviews'].idxmax
print("Actor with the highest mean for num_critic_for_reviews:", max_critics_actor)
print("Actor with the highest mean for num_user_for_reveiws", max_users_actor)
# Out:
# Actor with the highest mean for num_critic_for_reviews: Leonardo DiCaprio
# Actor with the highest mean for num_user_for_reveiws <bound method Series.idxmax of actor_1_name
# Brad Pitt            742.352941
# Leonardo DiCaprio    914.476190
# Meryl Streep         297.181818
# Name: num_user_for_reviews, dtype: float64>

# %% [markdown]
# **Checkpoint 6:** `Leonardo` has aced both the lists!

# %%
# Write the code for calculating decade here

Combined['decade'] = ((Combined['title_year'] // 10) * 10)
Combined['decade'] = Combined['decade'].astype(int).astype(str) + 's'
print("DataFrame with Decade Information:")
Combined[['movie_title', 'title_year', 'decade']]
# Out:
# DataFrame with Decade Information:
#                                           movie_title  title_year decade
# 0                                   It's Complicated       2009.0  2000s
# 1                                     The River Wild       1994.0  1990s
# 2                                      Julie & Julia       2009.0  2000s
# 3                              The Devil Wears Prada       2006.0  2000s
# 4                                    Lions for Lambs       2007.0  2000s
# 5                                      Out of Africa       1985.0  1980s
# 6                                       Hope Springs       2012.0  2010s
# 7                                     One True Thing       1998.0  1990s
# 8                                          The Hours       2002.0  2000s
# 9                                      The Iron Lady       2011.0  2010s
# 10                          A Prairie Home Companion       2006.0  2000s
# ...

# %%
# Write your code for creating the data frame df_by_decade here 

Combined['num_user_for_reviews'] = pd.to_numeric(Combined['num_user_for_reviews'], errors='coerce')
Combined_sorted = Combined.sort_values(by='decade')
df_by_decade = Combined_sorted.groupby('decade')['num_user_for_reviews'].sum().reset_index()
print("DataFrame by Decade with Sum of User Voted:")
df_by_decade
# Out:
# DataFrame by Decade with Sum of User Voted:
#   decade  num_user_for_reviews
# 0  1980s                 200.0
# 1  1990s                7699.0
# 2  2000s               15489.0
# 3  2010s               11705.0

# %%
# Write your code for plotting number of voted users vs decade

from matplotlib import pyplot as plt
import seaborn as sns

plt.figure(figsize=(6, 6))
plt.bar(df_by_decade['decade'],df_by_decade['num_user_for_reviews'],color='skyblue')
plt.xlabel('Decade')
plt.ylabel('Number of Voted Users')
plt.title('Number of Voted Users vs Decade')
plt.xticks(rotation=45, ha='right')
sns.set_style('whitegrid')
plt.tight_layout()
plt.show()
